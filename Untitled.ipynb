# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('iron.png')

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(10,8))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
print(img.shape)

pixels = img.reshape(-1,3)

print(pixels.shape)
# Out:
# (559, 818, 3)
# (457262, 3)

# %% [markdown]
# ## Extracting K most dominant colors

# %%
from sklearn.cluster import KMeans

# %%
dominant_colors = 10
km = KMeans(n_clusters=dominant_colors)

# %%
km.fit(pixels)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
print(km.cluster_centers_)
# Out:
# [[  7.86855753   6.77969659  10.6044338 ]
#  [ 58.0778791   49.08107276  57.51571819]
#  [ 42.02718659  70.00269679  95.38338192]
#  [ 23.40639015  25.24016543  32.2105826 ]
#  [ 87.95584062 105.97264162 124.50493813]
#  [ 10.47625104  15.79867775  23.92189487]
#  [130.65763052 204.0873494  231.92269076]
#  [ 35.93739416  36.70586792  46.27052298]
#  [ 75.35798865  72.38061638  82.03722628]
#  [ 22.75447086  15.51455124  19.6970864 ]]

# %%
centers = np.array(km.cluster_centers_,dtype='uint8')

# %%
print(centers)
# Out:
# [[  7   6  10]
#  [ 58  49  57]
#  [ 42  70  95]
#  [ 23  25  32]
#  [ 87 105 124]
#  [ 10  15  23]
#  [130 204 231]
#  [ 35  36  46]
#  [ 75  72  82]
#  [ 22  15  19]]

# %%
plt.figure(figsize=(10,4))
i=1
for color in centers:
    plt.subplot(1,dominant_colors,i)
    i+=1
    plt.axis('off')
    a = np.zeros((100,100,3),dtype='uint8')
    a[:,:,:]=color
    plt.imshow(a)
    
plt.show()

# %% [markdown]
# ### Segmenting the image

# %%
pixels.shape
# Out:
# (457262, 3)

# %%
km.labels_
# Out:
# array([5, 5, 5, ..., 0, 0, 0], dtype=int32)

# %%
km.labels_.shape
# Out:
# (457262,)

# %%
newimg = np.zeros(pixels.shape,dtype='uint8')
for i in range(pixels.shape[0]):
    newimg[i]=centers[km.labels_[i]]

# %%
newimg = newimg.reshape(img.shape)

# %%
plt.figure(figsize=(10,8))
plt.imshow(newimg)
